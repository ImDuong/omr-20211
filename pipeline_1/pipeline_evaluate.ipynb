# %% [markdown]
# # Load primus dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
shutil.copy('/content/drive/MyDrive/Comvis 20211/primus.tgz', '/content/')
# Out:
# '/content/primus.tgz'

# %%
# !mkdir /content/primus

# %%
# !tar -xvf "/content/primus.tgz" -C "/content/primus/"

# %% [markdown]
# # Pipeline method

# %%
# %cd /content/drive/MyDrive/Comvis\ 20211/pipeline
# Out:
# /content/drive/MyDrive/Comvis 20211/pipeline

# %% [markdown]
# ## Building the evaluation set

# %%
# !mkdir /content/eval_set

# %%
# !python build_evaluation_set.py -primus /content/primus/package_ab -output /content/eval_set -samples_count 300

# %%
# !python main.py -evaluate /content/eval_set
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:338: UserWarning: Trying to unpickle estimator LinearSVC from version 0.23.1 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   UserWarning,
#  13% 39/300 [00:29<02:59,  1.45it/s]index 119 is out of bounds for axis 0 with size 119
#  60% 180/300 [02:12<01:24,  1.42it/s]index 111 is out of bounds for axis 0 with size 111
#  74% 221/300 [02:42<01:04,  1.23it/s]index 105 is out of bounds for axis 0 with size 105
#  81% 243/300 [02:58<00:46,  1.23it/s]index 97 is out of bounds for axis 0 with size 97
#  99% 298/300 [03:40<00:01,  1.28it/s]index 119 is out of bounds for axis 0 with size 119
# 100% 300/300 [03:42<00:00,  1.35it/s]
# Finished !!

# %%
# !python ../evaluate_result.py -evaluate /content/eval_set -tolerance 5
# Out:
# 100% 300/300 [00:00<00:00, 7774.81it/s]
# Evaluation result: Model return the symbol error rate of 47.65, evaluated on 233 samples
